# %% [markdown]
# # Project 1 - Bank Transaction Gateway
#
# Following is the **structure** of the excel file containing information about your bank’s users.
#
# | Sr. No. |   User Id   |      A/c No.      |        Full Name         |  User Email   | A/c Balance | A/c Status |
# |---------|-------------|-------------------|--------------------------|---------------|-------------|------------|
# |    1    | 19091022001 | 2019091022IND0345 |        Karan Shah        | abc@gmail.com |     500     |   Active   |
# |    2    | 19091022002 | 2019091022IND1453 |        Manan Jain        | def@gmail.com |     1000    |   Active   |
# |    3    | 19091022003 | 2019091022IND5647 |        Kunal Patil       | xyz@gmail.com |     300     |   Active   |
# |    4    | 19091022004 | 2019091022IND3455 |        Ajay Ranade       | jkl@gmail.com |     450     |   Active   |
# |    5    | 19091022005 | 2019091022IND9823 |       Tushar Shinde      | pqr@gmail.com |     1560    |   Active   |
#
# Workbook Name - **SITIP19-VIT-Python-FinalProject1-Workbook.xlsx**
#
# Worksheet Name - **UserDetails**
#
# The project task is as follows:
#
# ### Stage 1 : User Validity
#
# - Ask user to enter Full Name or User ID
# - If Full Name / User ID not there then tell invalid User
# - If it exists, then ask user to enter Bank Account Number
# - If A/c number doesn't exist, then tell invalid user
# - If both are correct, then proceed to Stage 2
# - Give user three tries. If invalid input is given in all three tries then change account status from Active to Blocked and print Account Blocked and print quit program in Stage 1
#
# ### Stage 2: OTP Generation and Validity
#
# - Through code generate a 4 digit random OTP number
# - Send this OTP to that User via email
# - Then ask user to enter OTP from mail. Match this OTP with one generated in code.
# - If OTP matches then go to Stage 3. Else say Invalid OTP.
# - Give user three tries. If wrong OTP in all three tries then change account status from Active to Blocked and print Account Blocked and print quit program in Stage 2
#
# ### Stage 3 : Choice of Transaction
#
# - Ask user which type of transaction he wishes to do. ‘C’ for credit money and ‘D’ for debit money
# - If User enters any other input here then handle error and print Invalid Input. Again give user three tries and if all wrong then change account status from Active to Blocked and print Account Blocked and print quit program in Stage 3
# - If correct input then print current balance
# - Then ask user for amount to be credited or debited
# - Add or subtract amount entered by user to the current account balance and print the final account balance and write the same to account balance cells in excel workbook.
# - Print “Successful Transaction of Rs.______ completed”
# - **BONUS QUESTION: Print a proper mini-statement of the balance and display it. (2 points)**

# %%
import pandas as pd
import random 
import smtplib
import openpyxl
from openpyxl import load_workbook
otp = random.randint(1000,9999)
bank1=pd.ExcelFile('bank.xlsx')
bank2=pd.read_excel("bank.xlsx")
#bank2
b3=bank2[['User id','Full name','A/c no','A/c status','user email','A/c balance']]
b3
userid=input('pls enter your full name or user id')

count=0

for i in range(len(b3)):
    if str(b3['User id'][i])==userid or b3['Full name'][i]==userid:
        account_number=input("pls enter the account the number")
        for j in range(2):
            if b3['A/c no'][i]==account_number:
                
                otp1 = str(otp)
                email1=b3['user email'][i]
                server = smtplib.SMTP('smtp.gmail.com', port=587)
                server.starttls()
                server.login("bank.info.otp@gmail.com", "AXAJgnJ6gB4rpec")
                msg=("your otp is {0}".format(otp1))
                server.sendmail("bank.info.otp@gmail.com",email1, msg)
                server.quit()
                otp2 = input("check your mail and enter otp: ")
                
                for k in range(2):
                    if otp1==otp2:
                        trans = str(input("enter the transaction type"))   
                        print("bsdv")
                        trans1=trans.upper()
                        for l in range(2):
                            if trans.isalpha()==True:
                                if trans1 == 'C':
                                    amount1 = int(input("Enter the amount you want to credit: "))
                                    total = (b3['A/c balance'][i])+amount1
                                    print("the account balance is {0}".format(total))
                                    wb = load_workbook('bank.xlsx')
                                    sheet = wb['Sheet1']
                                    a=sheet.cell(row=i+2,column=6).coordinate
                                    #print(a)
                                    sheet[a]=(int(sheet[a].value))+amount1
                                    #print(sheet[a].value)
                                    wb.save('bank.xlsx')
                                    print("the successful transaction of Rs {0} is completed".format(amount1))
                                    print("")
                                    print("")
                                    x=b3['A/c no'][i]
                                    print("WELCOME TO BANK OF PYTHON\n")
                                    print("MINI STATEMENT")
                                    print("")
                                    print("")
                                    print("from A/c {0}xxxxxxx{1}".format(x[0:7],x[14:17]))
                                    print("DEPOSIT          {0}".format(amount1))
                                    print("AVAILABLE BAL    {0}".format(total))
                                    print("")
                                    print("")
                                    print("   TRANSACTION SUCCESSFUL     ")
                                    print("\n NEVER EVER SHARE YOUR ANY OF YOUR IMPORTANT \n CREDITIONALS SUCH AS ACCOUNT NUMBER/\n EXPIRY DATE / OTP / USER ID WITH ANYONE")
                                    break
                                    
                                if trans1 == 'D':
                                    amount2 = int(input("Enter the amount you want to debtit"))
                                    total1= (b3['A/c balance'][i])-amount2
                                    print("the account balance is {0}".format(total1))
                                    wb = load_workbook('bank.xlsx')
                                    sheet = wb['Sheet1']
                                    a=sheet.cell(row=i+2,column=6).coordinate
                                    #print(a)
                                    sheet[a]=(int(sheet[a].value))-amount2
                                    #print(sheet[a].value)
                                    wb.save('bank.xlsx')
                                    print("the successful transaction of Rs {0} is completed".format(amount2))
                                    print("")
                                    print("")
                                    x=b3['A/c no'][i]
                                    print("WELCOME TO BANK OF PYTHON\n")
                                

                                    print("MINI STATEMENT")
                                    print("")
                                    print("")
                                    print("from A/c {0}xxxxxxx{1}".format(x[0:7],x[14:17]))
                                    print("WITHDRAWL          {0}".format(amount2))
                                    print("AVAILABLE BAL    {0}".format(total1))
                                    print("")
                                    print("")
                                    print("   TRANSACTION SUCCESSFUL     ")
                                    print("\n NEVER EVER SHARE YOUR ANY OF YOUR IMPORTANT \n CREDITIONALS SUCH AS ACCOUNT NUMBER/\n EXPIRY DATE / OTP / USER ID WITH ANYONE")
                                    break
                                if trans1 != 'D' or trans1 != 'C':
                                    print("pls enter the valid input")
                                    trans = str(input("enter the transaction type"))
                                    count+=1
                                break
                                
                            else:
                                print("pls enter the valid input")
                                trans = str(input("enter the transaction type"))
                                count+=1 
                        break
                    else:
                        print("pls enter the valid otp")
                        otp2 = input("check your mail and enter otp: ")
                        count+=1       
                break
            else:
                print("pls enter the valid account number")
                account_number=input("pls enter the account the number")
                count+=1
        
        if count>2:
            bank2.loc[i,'A/c status'] ='Blocked'
            print("ACCOUNT BLOCKED")
            break
        break        
    else:
        print("Pls enter the valid user id or Full name ")
        userid=input('pls enter your full name or user id')
        break
#print(b3)
# Out:
# pls enter your full name or user id
# Pls enter the valid user id or Full name
# pls enter your full name or user id

# %%
import pandas as pd
import random
import smtplib
import openpyxl
from openpyxl import load_workbook

otp = random.randint(1000, 9999)
bank1 = pd.ExcelFile('bank.xlsx')
bank2 = pd.read_excel("bank.xlsx")
# bank2
b3 = bank2[['User id', 'Full name', 'A/c no', 'A/c status', 'user email', 'A/c balance']]
b3
userid = input('pls enter your full name or user id')

count = 0

for i in range(len(b3)):
    if str(b3['User id'][i]) == userid or b3['Full name'][i] == userid:
        account_number = input("pls enter the account the number")
        for j in range(2):
            if b3['A/c no'][i] == account_number:

                otp1 = str(otp)
                email1 = b3['user email'][i]
                server = smtplib.SMTP('smtp.gmail.com', port=587)
                server.starttls()
                server.login("bank.info.otp@gmail.com", "AXAJgnJ6gB4rpec")
                msg = ("your otp is {0}".format(otp1))
                server.sendmail("bank.info.otp@gmail.com", email1, msg)
                server.quit()
                otp2 = input("check your mail and enter otp: ")

                for k in range(2):
                    if otp1 == otp2:
                        trans = str(input("enter the transaction type"))
                        trans1 = trans.upper()
                        for l in range(2):
                            if trans1.isalpha():
                                if trans1 == 'C':
                                    amount1 = int(input("Enter the amount you want to credit: "))
                                    total = (b3['A/c balance'][i]) + amount1
                                    print("the account balance is {0}".format(total))
                                    wb = load_workbook('bank.xlsx')
                                    sheet = wb['Sheet1']
                                    a = sheet.cell(row=i + 2, column=6).coordinate
                                    # print(a)
                                    sheet[a] = (int(sheet[a].value)) + amount1
                                    # print(sheet[a].value)
                                    wb.save('bank.xlsx')
                                    print("the successful transaction of Rs {0} is completed".format(amount1))
                                    print("")
                                    print("")
                                    x = b3['A/c no'][i]
                                    print("WELCOME TO BANK OF PYTHON\n")
                                    print("MINI STATEMENT")
                                    print("")
                                    print("")
                                    print("from A/c {0}xxxxxxx{1}".format(x[0:7], x[14:17]))
                                    print("DEPOSIT          {0}".format(amount1))
                                    print("AVAILABLE BAL    {0}".format(total))
                                    print("")
                                    print("")
                                    print("   TRANSACTION SUCCESSFUL     ")
                                    print(
                                        "\n NEVER EVER SHARE YOUR ANY OF YOUR IMPORTANT \n CREDITIONALS SUCH AS ACCOUNT NUMBER/\n EXPIRY DATE / OTP / USER ID WITH ANYONE")
                                    break
                                elif trans1 == 'D':
                                    amount2 = int(input("Enter the amount you want to debtit"))
                                    total1 = (b3['A/c balance'][i]) - amount2
                                    print("the account balance is {0}".format(total1))
                                    wb = load_workbook('bank.xlsx')
                                    sheet = wb['Sheet1']
                                    a = sheet.cell(row=i + 2, column=6).coordinate
                                    # print(a)
                                    sheet[a] = (int(sheet[a].value)) - amount2
                                    # print(sheet[a].value)
                                    wb.save('bank.xlsx')
                                    print("the successful transaction of Rs {0} is completed".format(amount2))
                                    print("")
                                    print("")
                                    x = b3['A/c no'][i]
                                    print("WELCOME TO BANK OF PYTHON\n")

                                    print("MINI STATEMENT")
                                    print("")
                                    print("")
                                    print("from A/c {0}xxxxxxx{1}".format(x[0:7], x[14:17]))
                                    print("WITHDRAWL          {0}".format(amount2))
                                    print("AVAILABLE BAL    {0}".format(total1))
                                    print("")
                                    print("")
                                    print("   TRANSACTION SUCCESSFUL     ")
                                    print(
                                        "\n NEVER EVER SHARE YOUR ANY OF YOUR IMPORTANT \n CREDITIONALS SUCH AS ACCOUNT NUMBER/\n EXPIRY DATE / OTP / USER ID WITH ANYONE")
                                    break
                                else:
                                    print("pls enter the valid input")
                                    trans = str(input("enter the transaction type"))
                                    count += 1

                                   
                            else:
                                print("pls enter the valid input")
                                trans = str(input("enter the transaction type"))
                                count += 1
                        break
                    else:
                        print("pls enter the valid otp")
                        otp2 = input("check your mail and enter otp: ")
                        count += 1

                break
            else:
                print("pls enter the valid account number")
                account_number = input("pls enter the account the number")
                count += 1

        if count > 2:
            bank2.loc[i, 'A/c status'] = 'Blocked'
            print("ACCOUNT BLOCKED")
            break
        break
    else:
        print("Pls enter the valid user id or Full name ")
        userid = input('pls enter your full name or user id')
        break
# Out:
# pls enter your full name or user idAbhi Shah
# pls enter the account the number2019091022IND0345
# check your mail and enter otp: 3074
# enter the transaction typeh
# pls enter the valid input
# enter the transaction typec
# pls enter the valid input
# enter the transaction typec
# pls enter the valid input
# enter the transaction typec
# pls enter the valid input
# enter the transaction typec
# ACCOUNT BLOCKED

# %%
import random
# Out:
# 8252

# %%
for l in range(2):
                            if trans.isalpha()==True:
                                if trans.upper()=='C':
                                    print("dfkngkf")
                                    break
                                if trans.upper()=='D':
                                    print("rgvruighi")
                                    break
                                elif trans.upper!='C' or trans.upper()!="D":
                                    print("pls enter the valid input")
                                    trans=str(input("enter the transaction type"))
                                    break
                                break
                            else:
                                print("pls enter the valid input")
                                trans=str(input("enter the transaction type"))
                                break
                            break

# %%
import pandas as pd
import random 
import smtplib
import openpyxl
from openpyxl import load_workbook
otp = random.randint(1000,9999)
bank1=pd.ExcelFile('bank.xlsx')
bank2=pd.read_excel("bank.xlsx")
#bank2
b3=bank2[['User id','Full name','A/c no','A/c status','user email','A/c balance']]
b3
userid=input('pls enter your full name or user id')

count=0
count1=0
for i in range(len(b3)):
    if str(b3['User id'][i])==userid or b3['Full name'][i]==userid:
        print(i)
        account_number=input("pls enter the account the number")
        for j in range(2):
            if b3['A/c no'][i]==account_number:
                
                otp1 = str(otp)
                email1=b3['user email'][i]
                server = smtplib.SMTP('smtp.gmail.com', port=587)
                server.starttls()
                server.login("bank.info.otp@gmail.com", "AXAJgnJ6gB4rpec")
                msg=("your otp is {0}".format(otp1))
                server.sendmail("bank.info.otp@gmail.com",email1, msg)
                server.quit()
                otp2 = input("check your mail and enter otp: ")
                
                for k in range(2):
                    if otp1==otp2:
                        trans = str(input("enter the transaction type"))        
                        trans1=trans.upper()
                        for l in range(2):
                            if trans.isalpha():
                                if trans1 == 'C':
                                    amount1 = int(input("Enter the amount you want to credit: "))
                                    b3['A/c balance'][i] = (b3['A/c balance'][i])+amount1
                                    wb = load_workbook('bank.xlsx')
                                    sheet = wb['Sheet1']
                                    a=sheet.cell(row=i+2,column=6).coordinate
                                    print(a)
                                    sheet[a]=(int(sheet[a].value))+amount1
                                    print(sheet[a].value)
                                    wb.save('bank.xlsx')
                                    break
                                break
# Out:
# pls enter your full name or user idAbhi Shah
# 0
# pls enter the account the number2019091022IND0345
# check your mail and enter otp: 3506
# enter the transaction typec
# Enter the amount you want to credit: 200
# c:\users\abhi r shah\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# F2
# 900002200
# enter the transaction type
# check your mail and enter otp:

# %%
import openpyxl

wb = load_workbook('bank.xlsx')
sheet = wb['Sheet1']

for i in range(1,16):
    #print(sheet.cell(row=i+1,column=6).value)
    a=sheet.cell(row=i+1,column=6).coordinate
    sheet[a]=20
    print(sheet[a].value)

#print(type(sheet.cell(row=1,column=2).value))

# %%
again wait for a min
i m going in lift
okay
hello
you there 
yes say
i m getting fresh. you complete the code
i will come in a min
okay
2019091022IND0345
